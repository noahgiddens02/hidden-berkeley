# %% [markdown]
# # HW2: Publish a Web Page with GitHub Pages
#
# **COMPSS 211A · Fall 2026 · Due Sunday, October 4 at 11:59 p.m. Pacific**
#
# Publish a guide to Berkeley places and services, then change what it shows by editing its CSV data in this notebook.
#
# We supply a working website with eight resources. You will improve one existing entry, add one resource, and publish a guide with nine entries. You will also write a heading and introduction for your readers.
#
# **The workflow:** edit data in Jupyter → save the CSV → inspect, commit, and push in GitHub Desktop → check the website.
#
# GitHub builds the webpage from the CSV and our supplied layout. You only need to understand the short pandas steps below. No HTML, website-generation functions, or Git commands are required.
#
# Submit this completed notebook with your repository link, website link, three commit IDs and messages, and a short explanation.

# %% [markdown]
# ## 1. Create your website repository
#
# 1. Open the [HW2 starter template](https://github.com/macss-berkeley/hw2-hidden-berkeley-template). Choose **Use this template → Create a new repository**. Select your account, name the repository `hidden-berkeley`, and choose **Public**. If you already used that name for earlier practice, choose `hidden-berkeley-hw2`.
# 2. In GitHub Desktop, choose **File → Clone Repository → URL** and paste the URL of **your new repository**. Clone it outside your course repository.
# 3. Open that complete folder in VS Code. Open the `hw2_hidden_berkeley.ipynb` inside it. Work in this copy throughout the assignment. If you are reading the copy in the course repository, switch to your new repository now.
# 4. Select the course Python environment you used in Weeks 1–2 as the notebook kernel. If it is not listed, select the Python interpreter in the course repository's `.venv` folder: `.venv/bin/python` on macOS/Linux or `.venv\Scripts\python.exe` on Windows. See the [course setup guide](https://github.com/macss-berkeley/compss-211a/blob/main/SETUP.md) if you have not completed that setup.
#
# A template gives you a new repository containing the starter files. It already exists on GitHub, so subsequent uploads use **Push origin** in Desktop.
#
# | File | Your work |
# | --- | --- |
# | `docs/_data/locations.csv` | Edit this data through the notebook. Each row becomes one website entry. |
# | `docs/index.md` | Edit the heading and introduction near the top. |
# | `README.md` | Explain your guide, source, and website checks. |
# | This notebook | Save your data-editing code, outputs, and evidence. |
#
# The supplied layout and configuration files need no edits.

# %% [markdown]
# ## 2. Publish the starter website
#
# Do this before changing the data so you can see the starting point.
#
# 1. Open **your repository** on GitHub. Go to **Settings → Pages**.
# 2. Under **Build and deployment → Source**, choose **Deploy from a branch**. Select **main**, choose **/docs**, and select **Save**.
# 3. Wait for the deployment to finish. The repository's **Actions** tab shows its progress. Open the website address shown in Pages settings. The first build can take a few minutes.
# 4. Find Morrison Library on the page. Later you will compare the page with its row in the CSV.
#
# Your repository URL (`github.com/noahgiddens02/hidden-berkeley`) shows the files and history. Your website URL (`noahgiddens02.github.io/hidden-berkeley/`) opens the guide. Record your actual URLs in section 6.
#
# In `docs/index.md`, change `# Hidden Berkeley` to your chosen heading and replace the introduction with two sentences for someone new to Berkeley. Keep the opening `---` block and the supplied loop below the introduction.
#
# **Commit 1:** save the file. In Desktop, select your HW2 repository, inspect the `docs/index.md` diff under **Changes**, and check only intended files. Enter a descriptive **Summary**, select **Commit to main**, then **Push origin**. After the build finishes, check the heading and introduction on your website.

# %% [markdown]
# ## 3. Read the website's CSV
#
# The cell below loads the actual CSV used by the website. `index_col="location_id"` uses each resource's identifier as its row label, so we can select a row with `.loc["HB03"]`.
#
# The columns describe the resource's name, category, area, access information, and official webpage. Find Morrison Library in the displayed table and compare it with the website.
#
# Run the notebook from your HW2 repository folder. If the CSV is not found, check that you opened that complete folder and its notebook in VS Code.

# %%
import pandas as pd

csv_path = "docs/_data/locations.csv"
locations = pd.read_csv(csv_path, index_col="location_id")
locations
# Out:
#                                                      name           category  \
# location_id
# HB01                                                D-Lab    methods support
# HB02                 BAMPFA Film Library and Study Center     media research
# HB03                                     Morrison Library      quiet reading
# HB04                          Jacobs Institute Makerspace        prototyping
# HB05                                   Basic Needs Center    student support
# HB06                           Disabled Students' Program     access support
# HB07         Berkeley Art Museum and Pacific Film Archive  arts and archives
# HB08                                  UC Botanical Garden  field observation
#
#                                  area  \
# location_id
# HB01         Social Sciences Building
# HB02                Downtown Berkeley
# HB03                      Doe Library
# HB04                     North campus
# HB05                      UC Berkeley
# ...

# %% [markdown]
# ## 4. Improve one entry and add a resource
#
# Open an existing resource's official webpage. Improve its access note with a specific, useful detail you can verify there. For example, clarify who can use it or where to check visiting arrangements. Replace the two placeholder strings below; keep the identifier of a resource already in the table.
#
# `.loc[row_label, column_name]` selects one cell. Assigning a string changes that cell in the DataFrame. The last line displays your updated row. This has not saved the CSV yet.

# %%
existing_id = "HB01"  # Change this if you choose another existing resource.
locations.loc['HB01', "access_note"] = "Consult workshop tab for most uses."
locations.loc['HB01', "source_url"] = "https://dlab.berkeley.edu/"
locations.loc['HB01', 'area'] = 'Social Science Building, third floor'
locations.loc['HB01']
# Out:
# name                                          D-Lab
# category                            methods support
# area           Social Science Building, third floor
# access_note     Consult workshop tab for most uses.
# source_url               https://dlab.berkeley.edu/
# Name: HB01, dtype: str

# %% [markdown]
# Now choose one Berkeley place or service that is not already listed. Check its official webpage and replace every placeholder in this dictionary. Use public information and retain all eight original resources.
#
# The dictionary keys match the CSV columns. `.loc["HB09"] = new_resource` puts those values in a row labeled `HB09`. Running it again replaces that same row, so rerunning the notebook does not add duplicates.

# %%
new_resource = {
    "name": "Labor Center",
    "category": "Union support/research",
    "area": "OFF CAMPUS Labor Center",
    "access_note": "Open by appointment",
    "source_url": "https://laborcenter.berkeley.edu/",
}

locations.loc["HB09"] = new_resource
locations
# Out:
#                                                      name  \
# location_id
# HB01                                                D-Lab
# HB02                 BAMPFA Film Library and Study Center
# HB03                                     Morrison Library
# HB04                          Jacobs Institute Makerspace
# HB05                                   Basic Needs Center
# HB06                           Disabled Students' Program
# HB07         Berkeley Art Museum and Pacific Film Archive
# HB08                                  UC Botanical Garden
# HB09                                         Labor Center
#
#                            category                                  area  \
# location_id
# HB01                methods support  Social Science Building, third floor
# HB02                 media research                     Downtown Berkeley
# HB03                  quiet reading                           Doe Library
# ...

# %% [markdown]
# ### Save your data changes
#
# Check the table above before saving: nine rows, all eight original identifiers (`HB01`–`HB08`), your improved entry, and your new `HB09` entry. Replace every placeholder and make sure both source links open the official pages you checked.
#
# The first line below writes the DataFrame back to the website's CSV, including the `location_id` row labels. The second line reads the saved file again so you can verify what is on disk. Changing a DataFrame in memory does not update the file until you call `to_csv`.
#
# Do not use `index=False` here: the website CSV needs those identifiers.

# %%
locations.to_csv(csv_path, index_label="location_id")
pd.read_csv(csv_path)
# Out:
#   location_id                                          name  \
# 0        HB01                                         D-Lab
# 1        HB02          BAMPFA Film Library and Study Center
# 2        HB03                              Morrison Library
# 3        HB04                   Jacobs Institute Makerspace
# 4        HB05                            Basic Needs Center
# 5        HB06                    Disabled Students' Program
# 6        HB07  Berkeley Art Museum and Pacific Film Archive
# 7        HB08                           UC Botanical Garden
# 8        HB09                                  Labor Center
#
#                  category                                  area  \
# 0         methods support  Social Science Building, third floor
# 1          media research                     Downtown Berkeley
# 2           quiet reading                           Doe Library
# 3             prototyping                          North campus
# ...

# %% [markdown]
# ## 5. Push the data and check the website
#
# **Commit 2:** save this notebook. In Desktop, inspect the CSV diff. Find the existing entry you changed and the new `HB09` row. Commit the CSV and notebook with a message describing the data changes, then **Push origin**.
#
# Open the CSV on GitHub and check that the edits arrived. Wait for the Pages build to finish, then open your website in a private browser window. Check that:
#
# - All nine resources appear, including the one you added.
# - The improved access note matches the CSV.
# - Your new resource's details match the CSV, and the official links work.
# - Your heading and introduction appear.
#
# The supplied loop in `docs/index.md` tells GitHub's website builder to display each CSV row. GitHub rebuilds the page after a push. You do not copy rows into Markdown or run website-building code in Jupyter.
#
# If GitHub has the updated CSV but the website is old, check the latest deployment in **Actions** and refresh after it finishes.
#
# Edit the **Purpose and sources** and **Website checks** sections of `README.md`. State who the guide is for, name and link your added resource, and describe what you actually checked. Commit and push these changes as **commit 3**. The template's initial commit does not count toward your three commits.

# %% [markdown]
# ## 6. Record your work
#
# Fill in the URLs below. In Desktop's **History**, select each of your three commits and copy its commit ID (hash/SHA) and message into `GIT_LOG`, one per line. Short or full IDs are fine. Use your actual history; no terminal output is needed.

# %%
REPOSITORY_URL = "https://github.com/noahgiddens02/hidden-berkeley"
PAGES_URL = "https://noahgiddens02.github.io/hidden-berkeley/"
GIT_LOG = """
926ae91df380f5f01d49f4761d93673c3c6d62b4
1aa898bbf056215b3bd06fe19b2e155ec8f0e64c
6a684b534f699e081d1db121c4cd22abd93716b9
"""

# %% [markdown]
# ### Your explanation
#
# In four to six sentences, describe one specific CSV change and follow it from the DataFrame in memory to the saved CSV, the local commit, GitHub, and the published page. Explain what you checked on the website and what you found. End with your AI-use disclosure.
#
# > For step 4 " Improve one entry and add a resource", we added an addional entry onto the dataframe. We then saved the current project and committed it to the local GitHub desktop save. After that we then pushed the change to our GitHub repo. Finally, we checked to make sure that the website updated.
#
# No AI was used in this homework assignment.

# %% [markdown]
# ## Submit
#
# 1. Fill in the links, commit evidence, and explanation above. Remove all `REPLACE` placeholders from your data-editing cells.
# 2. Restart the kernel and run the notebook from top to bottom. It should still show nine resources: assigning `HB09` again updates that row. Check the saved CSV output.
# 3. Save the completed notebook. Commit and push any remaining notebook or CSV changes. Extra commits are fine; the three evidence commits can remain the earlier ones.
# 4. Check the finished website once more after the final build. Save a copy of the completed notebook as `lastname_firstname_hw2.ipynb` and upload that file to bCourses. Keep the notebook in your repository as well. Submit only the `.ipynb`; the links inside it lead to your repository and website.
#
# **AI and collaboration:** Please don't use AI to perform or fabricate the required repository workflow. Complete and explain your own work. Use public resource information and cite the official pages you checked. Disclose any permitted help in your response.
#
# References: [GitHub Pages publishing settings](https://docs.github.com/en/pages/getting-started-with-github-pages/configuring-a-publishing-source-for-your-github-pages-site), [GitHub Desktop history](https://docs.github.com/en/desktop/making-changes-in-a-branch/viewing-the-branch-history-in-github-desktop).
